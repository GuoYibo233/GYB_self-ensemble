# %%
from functools import partial
from notebooks._utils import report_series_ensemble_accuracy_by_nparas
from notebooks._utils import calculate_baseline_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
num_fewshots = 0
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it", "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_series_ensemble_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=num_fewshots)
    
    print("---- Calculating baseline ----")
    calculate_baseline_accuracy(dataset_root, model_name, num_fewshots)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=False)
    
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=True, scale_score=False)
    
    print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=False, scale_score=True)

    print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=True)
    
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.1426 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.0739 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.0854 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.0471 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0579 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.0993 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.1263 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.2172 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.2036 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.2401 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.1386 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.2072 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.2577 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2171 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.2902 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.3317 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4024 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4245 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3095 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0079 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4475 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4221 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4575 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3645 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4006 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4436 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3135 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0281 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4434 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4038 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4540 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.4536 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5597 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5169 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4419 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0320 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5543 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5745 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5666 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4600 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5550 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5189 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3863 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1064 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5060 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5120 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5497 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b ===================
# ---- Calculating baseline ----
# Acc: 0.1792 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.2428 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3174 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.1707 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.2892 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3488 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.3196 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3423 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3726 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3825 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2338 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1096 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4063 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4030 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4266 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b ===================
# ---- Calculating baseline ----
# Acc: 0.1132 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4271 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4268 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3174 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0665 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.3436 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4700 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4442 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3760 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4288 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4124 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3395 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1020 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.3961 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4586 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4591 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_14b ===================
# ---- Calculating baseline ----
# Acc: 0.2804 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4308 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0077 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./modifyattn.scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_14b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4832 ==> 🏷️ baseline
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5431 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4968 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Error reading /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama/qwen2.5_14b_it/myriadlama.scalescore.singleparaqapair.0fshots.5samples.5paras.feather: Verification of flatbuffer-encoded Footer failed.
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./modifyattn.scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
