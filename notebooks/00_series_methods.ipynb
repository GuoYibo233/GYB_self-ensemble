# %%
from functools import partial
from notebooks._utils import report_series_ensemble_accuracy_by_nparas
from notebooks._utils import calculate_series_ensemble_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it", "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_series_ensemble_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=5,)
    
    print("---- Calculating baseline ----")
    df = calculate_series_ensemble_accuracy(
        dump_file_prefix=dump_file_prefix, 
        single_para_qapair=True, explicit_prompts=False, repeat_paras=False, 
        modifyattn=False, modifyrope=False, scale_score=False, 
        num_paraphrases=1, num_fewshots=5, use_generation=True)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=False)
    
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=True, scale_score=False)
    
    print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=False, scale_score=True)

    print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=True)
    
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.3866 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3205 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4218 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2634 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0320 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4441 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4465 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4690 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3501 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3780 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3758 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3425 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0262 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.3977 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3924 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4086 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4808 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5457 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5289 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4710 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0462 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5329 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5557 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5608 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4050 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4720 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4497 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3716 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0388 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4629 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4721 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4800 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.5961 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6694 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0359 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.6631 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6875 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6961 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5635 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6385 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6150 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5168 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1905 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.6269 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6445 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6578 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b ===================
# ---- Calculating baseline ----
# KeyError: 'generation_lemmas' ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4134 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4467 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# KeyError: 'generation_lemmas' ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0655 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4654 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4804 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4916 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4115 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4415 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4409 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3475 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0439 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4600 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4652 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4824 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b ===================
# ---- Calculating baseline ----
# Acc: 0.4898 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5113 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5093 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4670 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0161 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5112 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5425 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5421 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4524 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4974 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4744 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4206 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1318 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4853 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5035 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5103 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_14b ===================
# ---- Calculating baseline ----
# Acc: 0.5381 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5716 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5759 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5244 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0011 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./modifyattn.scalescore.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6072 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore.singleparaqapair.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_14b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5259 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5806 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5633 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5257 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0017 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5745 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5875 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore.singleparaqapair.5samples.5paras.feather does not exist!

# %%
# answers = [answers.tolist() for answers in para2["answer_lemmas"].tolist()]
# uuids = para2['uuid'].tolist()
# pred2, prompt2 = para2['predict_lemma'].tolist(), para2['paraphrases'].tolist()
# pred3, prompt3 = para3['predict_lemma'].tolist(), para3['paraphrases'].tolist()
# pred4, prompt4 = para4['predict_lemma'].tolist(), para4['paraphrases'].tolist()
# pred5, prompt5 = para5['predict_lemma'].tolist(), para5['paraphrases'].tolist()

# %%
# # for ans, p0, p2, p3, p4, p5 in zip(answers, base, pred2, pred3, pred4, pred5):
# iterator = zip(uuids, answers, pred2, prompt2, pred3, prompt3, pred4, prompt4, pred5, prompt5)
# for idx, (uuid, ans, p2, pp2, p3, pp3, p4, pp4, p5, pp5) in enumerate(iterator):
#     ans = [a.tolist() for a in ans]
#     baseline_sdf = baseline[baseline["uuid"] == uuid]
#     prompt = baseline_sdf["paraphrase"].tolist()[0]
#     pp2 = pp2.tolist()
#     pp3 = pp3.tolist()
#     pp4 = pp4.tolist()
#     pp5 = pp5.tolist()
    
#     pp2_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp2]
#     pp3_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp3]
#     pp4_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp4]
#     pp5_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp5]
#     print("===")
#     print("Question:", prompt)
#     print("Answers:", ans)
#     print("Per-prompt predictions:", baseline_sdf["predict_lemma"].tolist())
#     # print("Baseline Prediction:", p0)
#     print(f"2-para Prediction:\t'{p2}' from: {pp2_sep_predicts}")
#     print(f"3-para Prediction:\t'{p3}' from: {pp3_sep_predicts}")
#     print(f"4-para Prediction:\t'{p4}' from: {pp4_sep_predicts}")
#     print(f"5-para Prediction:\t'{p5}' from: {pp5_sep_predicts}")
#     print()
