# %%
from functools import partial
from notebooks._utils import report_series_ensemble_accuracy_by_nparas
from notebooks._utils import calculate_baseline_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
num_fewshots = 5
# , "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_series_ensemble_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=num_fewshots)
    
    print("---- Calculating baseline ----")
    calculate_baseline_accuracy(dataset_root, model_name, num_fewshots)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=False)
    
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=True, scale_score=False)
    
    print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=False, scale_score=True)

    print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=True)
    
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.3672 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.4090 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3198 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4218 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2633 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0320 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4439 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4460 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4687 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3149 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.3550 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3790 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3758 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3426 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0263 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.3977 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3926 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4086 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4612 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.5140 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5454 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5291 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4713 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0468 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5332 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5556 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5612 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3785 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.4410 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4723 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4498 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3744 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0388 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4629 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4722 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4800 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.5642 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.6205 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6698 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6511 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5886 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0356 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.6636 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6879 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6966 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5268 ==> 🏷️ baseline of average accuracy per-paraphrase
# Acc: 0.5995 ==> 🏷️ baseline of max accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6389 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6153 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5505 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1904 ==> 🏷️ 5paras 5shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.6272 ==> 🏷️ 5paras 5shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6444 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6581 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
