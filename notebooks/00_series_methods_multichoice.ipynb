# %%
from functools import partial
from notebooks._utils import report_series_ensemble_accuracy_by_nparas
from notebooks._utils import calculate_baseline_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
num_fewshots = 0
# , "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_series_ensemble_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=num_fewshots)
    
    print("---- Calculating baseline ----")
    calculate_baseline_accuracy(dataset_root, ds_name, model_name, num_fewshots, is_multichoice=False, by_probs=False)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=False)
    
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=True, scale_score=False)
    
    print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=False, modifyrope=False, scale_score=True)

    print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=False, scale_score=True)
    
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=True, modifyrope=True, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.1557 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.0828 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.1036 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.0517 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# File ./scalescore.singleparaqapair.0fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0911 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.1080 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.1451 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.2245 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.2045 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.2426 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.1404 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.2067 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.2579 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2253 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.2909 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.3417 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4055 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4272 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3222 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0063 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4507 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4276 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4624 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3669 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4085 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4453 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3247 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0281 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.4477 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4144 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4578 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.4580 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5600 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5189 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4495 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.0304 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5556 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5756 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5696 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4641 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5553 ==> 🏷️ 5paras 0shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5203 ==> 🏷️ 5paras 0shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4044 ==> 🏷️ 5paras 0shots 1QA    +Rope
# ---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.1146 ==> 🏷️ 5paras 0shots 1QA     +ScaleScore
# ---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----
# Acc: 0.5075 ==> 🏷️ 5paras 0shots 1QA   +Attn  +ScaleScore
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5371 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5656 ==> 🏷️ 5paras 0shots 1QA   +Attn +Rope +ScaleScore
