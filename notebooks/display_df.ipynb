# %%
import pandas as pd

filename1 = "/home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama/llama3.2_1b_it/myriadlama.modifyattn.modifyrope.repeatparas.singleparaqapair.5samples.2paras.feather"
filename2 = "/home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama/llama3.2_3b_it/myriadlama.modifyattn.modifyrope.repeatparas.singleparaqapair.5samples.2paras.feather"

# %%
pd.read_feather(filename1)
# Out:
#                                  uuid  \
# 0     5d09424876ba7f4-15e8746c51e1d4c
# 1     5d09424876ba7f4-15e8746c51e1d4c
# 2     5d09424876ba7f4-15e8746c51e1d4c
# 3     5d09424876ba7f4-15e8746c51e1d4c
# 4     5d09424876ba7f4-15e8746c51e1d4c
# ...                               ...
# 9995  9e74549729da44f-cdcb59adf18e302
# 9996  9e74549729da44f-cdcb59adf18e302
# 9997  9e74549729da44f-cdcb59adf18e302
# 9998  9e74549729da44f-cdcb59adf18e302
# 9999  9e74549729da44f-cdcb59adf18e302
#
#                                                 answers prediction generation  \
# 0                  [NBC, National Broadcasting Company]        CBS        CBS
# 1                  [NBC, National Broadcasting Company]        CBS        CBS
# 2                  [NBC, National Broadcasting Company]        CBS        CBS
# 3                  [NBC, National Broadcasting Company]        CBS        CBS
# 4                  [NBC, National Broadcasting Company]        CBS        CBS
# ...

# %%
pd.read_feather(filename2)
# Out:
#                                  uuid  \
# 0     5d09424876ba7f4-15e8746c51e1d4c
# 1     5d09424876ba7f4-15e8746c51e1d4c
# 2     5d09424876ba7f4-15e8746c51e1d4c
# 3     5d09424876ba7f4-15e8746c51e1d4c
# 4     5d09424876ba7f4-15e8746c51e1d4c
# ...                               ...
# 9995  9e74549729da44f-cdcb59adf18e302
# 9996  9e74549729da44f-cdcb59adf18e302
# 9997  9e74549729da44f-cdcb59adf18e302
# 9998  9e74549729da44f-cdcb59adf18e302
# 9999  9e74549729da44f-cdcb59adf18e302
#
#                                                 answers  prediction  \
# 0                  [NBC, National Broadcasting Company]         NBC
# 1                  [NBC, National Broadcasting Company]         ABC
# 2                  [NBC, National Broadcasting Company]  television
# 3                  [NBC, National Broadcasting Company]  television
# 4                  [NBC, National Broadcasting Company]        1952
# ...                                                 ...         ...
# ...
