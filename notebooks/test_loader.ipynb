# %%
import random
import itertools

from numpy import repeat

base = [1,2,3, 4,5,6]

all_repeats = list([[n]*3 for n in base])
all_permutations = list(itertools.permutations(base, 3))

# %%
all_repeats
# Out:
# [[1, 1, 1], [2, 2, 2], [3, 3, 3], [4, 4, 4], [5, 5, 5], [6, 6, 6]]

# %%
all_permutations
# Out:
# [(1, 2, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 2, 6),
#  (1, 3, 2),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 3, 6),
#  (1, 4, 2),
#  (1, 4, 3),
#  (1, 4, 5),
#  (1, 4, 6),
#  (1, 5, 2),
#  (1, 5, 3),
#  (1, 5, 4),
#  (1, 5, 6),
#  (1, 6, 2),
#  (1, 6, 3),
#  (1, 6, 4),
#  (1, 6, 5),
#  (2, 1, 3),
#  (2, 1, 4),
#  (2, 1, 5),
#  (2, 1, 6),
#  (2, 3, 1),
#  (2, 3, 4),
#  (2, 3, 5),
#  (2, 3, 6),
#  (2, 4, 1),
#  (2, 4, 3),
#  (2, 4, 5),
#  (2, 4, 6),
#  (2, 5, 1),
#  (2, 5, 3),
#  (2, 5, 4),
#  (2, 5, 6),
#  (2, 6, 1),
#  (2, 6, 3),
#  (2, 6, 4),
#  (2, 6, 5),
#  (3, 1, 2),
#  (3, 1, 4),
#  (3, 1, 5),
#  (3, 1, 6),
#  (3, 2, 1),
#  (3, 2, 4),
#  (3, 2, 5),
#  (3, 2, 6),
#  (3, 4, 1),
#  (3, 4, 2),
#  (3, 4, 5),
#  (3, 4, 6),
#  (3, 5, 1),
#  (3, 5, 2),
#  (3, 5, 4),
#  (3, 5, 6),
#  (3, 6, 1),
#  (3, 6, 2),
#  (3, 6, 4),
#  (3, 6, 5),
#  (4, 1, 2),
#  (4, 1, 3),
#  (4, 1, 5),
#  (4, 1, 6),
#  (4, 2, 1),
#  (4, 2, 3),
#  (4, 2, 5),
#  (4, 2, 6),
#  (4, 3, 1),
#  (4, 3, 2),
#  (4, 3, 5),
# ...

# %%
data = random.sample(all_permutations, k=5)
data
# Out:
# [(1, 2, 3), (3, 3, 1), (3, 1, 3), (3, 2, 1), (1, 2, 2)]

# %%
import torch
sample_dataloader = torch.utils.data.DataLoader(
    data, batch_size=2, shuffle=False)
    
for batch in sample_dataloader:
    print(batch)
# Out:
# [tensor([3, 1]), tensor([2, 2]), tensor([1, 3])]
# [tensor([2, 1]), tensor([1, 3]), tensor([3, 2])]
# [tensor([3]), tensor([1]), tensor([2])]

# %%
answers = [answers.tolist() for answers in baseline["answers"].tolist()]
prompts = baseline['question'].tolist()
base = baseline['prediction'].tolist()
pred2 = twopara['prediction'].tolist()
pred3 = threepara['prediction'].tolist()
pred4 = fourpara['prediction'].tolist()
pred5 = fivepara['prediction'].tolist()
