# %%
import pandas
from functools import partial
from notebooks._utils import report_accuracy
from notebooks._utils import _calculate_accuracy

ds_name = "myriadlama-debug"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

model_name = "llama3.2_3b_it"
# model_name = "qwen2.5_3b_it"
dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."

report_accuracy = partial(
    report_accuracy,
    dump_file_prefix=dump_file_prefix,
    single_para_qapair=False,
    explicit_prompts=True,
    repeat_paras=False)

# %%
baseline_fn = f"{dataset_root}/{ds_name}/{model_name}/baseline_per_prompt.feather"
baseline = pandas.read_feather(baseline_fn)
baseline["predict_lemma"] = baseline["predict_lemma"].apply(lambda xs: xs[0])
_calculate_accuracy(baseline, "MyriadLlama Baseline Per Prompt")
# Out:
# MyriadLlama Baseline Per Prompt Accuracy: 0.3990

# %%
print("=== No attention or rope modifications, single QA section ===")
modifyattn, modifyrope = False, False
print("--- Without score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
print("--- With score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)
print()

print("=== With only attention modifications, single QA section ===")
modifyattn, modifyrope = True, False
print("--- Without score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
print("--- With score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)
print()


print("=== With attention and rope modifications, single QA section ===")
modifyattn, modifyrope = True, True
print("--- Without score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
print("--- With score scaling ---")
report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)
print()
# Out:
# === No attention or rope modifications, single QA section ===
# --- Without score scaling ---
# MyriadLlama    2 Paras Accuracy: 0.1010
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.explicitprompts.5samples.4paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.explicitprompts.5samples.5paras.feather does not exist!
# --- With score scaling ---
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.scalescore20.explicitprompts.5samples.2paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.scalescore20.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.scalescore20.explicitprompts.5samples.4paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.scalescore20.explicitprompts.5samples.5paras.feather does not exist!
#
# === With only attention modifications, single QA section ===
# --- Without score scaling ---
# MyriadLlama +Attn   2 Paras Accuracy: 0.1200
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.explicitprompts.5samples.4paras.feather does not exist!
# MyriadLlama +Attn   5 Paras Accuracy: 0.1240
# --- With score scaling ---
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.scalescore20.explicitprompts.5samples.2paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.scalescore20.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.scalescore20.explicitprompts.5samples.4paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.scalescore20.explicitprompts.5samples.5paras.feather does not exist!
#
# === With attention and rope modifications, single QA section ===
# --- Without score scaling ---
# MyriadLlama +Attn +Rope  2 Paras Accuracy: 0.1250
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.modifyrope.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.modifyrope.explicitprompts.5samples.4paras.feather does not exist!
# MyriadLlama +Attn +Rope  5 Paras Accuracy: 0.1250
# --- With score scaling ---
# MyriadLlama +Attn +Rope  2 Paras Accuracy: 0.1250
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.modifyrope.scalescore20.explicitprompts.5samples.3paras.feather does not exist!
# File /home/xzhao/workspace/GYB_self-ensemble/datasets/myriadlama-debug/llama3.2_3b_it/myriadlama.modifyattn.modifyrope.scalescore20.explicitprompts.5samples.4paras.feather does not exist!
# MyriadLlama +Attn +Rope  5 Paras Accuracy: 0.1250

# %%
print("=== No rope modifications or score scaling, single QA section ===")
scale_score, modifyrope, repeat_paras = False, False, False
print("--- Without attention modifications ---")
report_accuracy(dump_file_prefix, modifyattn=False, modifyrope=modifyrope, scale_score=scale_score, repeat_paras=repeat_paras)
print("--- With attention modifications ---")
report_accuracy(dump_file_prefix, modifyattn=True, modifyrope=modifyrope, scale_score=scale_score, repeat_paras=repeat_paras)

# %%
print("=== With attention modifications but no score scaling, single QA section ===")
modifyattn, scale_score, repeat_paras = True, False, False
print("--- Without rope modifications ---")
report_accuracy(dump_file_prefix, modifyattn=modifyattn, modifyrope=False, scale_score=scale_score, repeat_paras=repeat_paras)
print("--- With rope modifications ---")
report_accuracy(dump_file_prefix, modifyattn=modifyattn, modifyrope=True, scale_score=scale_score, repeat_paras=repeat_paras)

# %%
# answers = [answers.tolist() for answers in para2["answer_lemmas"].tolist()]
# uuids = para2['uuid'].tolist()
# pred2, prompt2 = para2['predict_lemma'].tolist(), para2['paraphrases'].tolist()
# pred3, prompt3 = para3['predict_lemma'].tolist(), para3['paraphrases'].tolist()
# pred4, prompt4 = para4['predict_lemma'].tolist(), para4['paraphrases'].tolist()
# pred5, prompt5 = para5['predict_lemma'].tolist(), para5['paraphrases'].tolist()

# %%
# # for ans, p0, p2, p3, p4, p5 in zip(answers, base, pred2, pred3, pred4, pred5):
# iterator = zip(uuids, answers, pred2, prompt2, pred3, prompt3, pred4, prompt4, pred5, prompt5)
# for idx, (uuid, ans, p2, pp2, p3, pp3, p4, pp4, p5, pp5) in enumerate(iterator):
#     ans = [a.tolist() for a in ans]
#     baseline_sdf = baseline[baseline["uuid"] == uuid]
#     prompt = baseline_sdf["paraphrase"].tolist()[0]
#     pp2 = pp2.tolist()
#     pp3 = pp3.tolist()
#     pp4 = pp4.tolist()
#     pp5 = pp5.tolist()
    
#     pp2_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp2]
#     pp3_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp3]
#     pp4_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp4]
#     pp5_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp5]
#     print("===")
#     print("Question:", prompt)
#     print("Answers:", ans)
#     print("Per-prompt predictions:", baseline_sdf["predict_lemma"].tolist())
#     # print("Baseline Prediction:", p0)
#     print(f"2-para Prediction:\t'{p2}' from: {pp2_sep_predicts}")
#     print(f"3-para Prediction:\t'{p3}' from: {pp3_sep_predicts}")
#     print(f"4-para Prediction:\t'{p4}' from: {pp4_sep_predicts}")
#     print(f"5-para Prediction:\t'{p5}' from: {pp5_sep_predicts}")
#     print()
