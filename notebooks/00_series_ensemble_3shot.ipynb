# %%
from functools import partial
from notebooks._utils import report_accuracy_by_nparas
from notebooks._utils import calculate_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it", "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=3)
    
    print("---- Calculating baseline ----")
    df = calculate_accuracy(
        dump_file_prefix=dump_file_prefix, 
        single_para_qapair=True, explicit_prompts=False, repeat_paras=False, 
        modifyattn=False, modifyrope=False, scale_score=0, 
        num_paraphrases=1, num_fewshots=3)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    # print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    # report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)

    modifyattn, modifyrope = True, False
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    modifyattn, modifyrope = False, True
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)

    
    # print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    # report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)

    modifyattn, modifyrope = True, True
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.3453 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3120 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4061 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.2662 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4183 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4146 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3255 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3300 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3579 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3227 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3686 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.3681 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4569 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5285 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5170 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4534 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5303 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5289 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3886 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4585 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4471 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3738 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4642 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4615 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.5768 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6564 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6476 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5411 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6284 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6137 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4895 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6399 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6391 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4039 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3731 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4345 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3329 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4671 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3971 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4359 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4346 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3316 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4590 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4535 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b ===================
# ---- Calculating baseline ----
# Acc: 0.4770 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_7b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4373 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_14b ===================
# ---- Calculating baseline ----
# Acc: 0.5223 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_14b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5229 ==> 🏷️ 1paras 3shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5788 ==> 🏷️ 5paras 3shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5587 ==> 🏷️ 5paras 3shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5108 ==> 🏷️ 5paras 3shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5846 ==> 🏷️ 5paras 3shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.3fshots.5samples.5paras.feather does not exist!
