# %%
from functools import partial
from notebooks._utils import report_accuracy_by_nparas
from notebooks._utils import calculate_accuracy

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it", "qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it"]:
    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=5)
    
    print("---- Calculating baseline ----")
    df = calculate_accuracy(
        dump_file_prefix=dump_file_prefix, 
        single_para_qapair=True, explicit_prompts=False, repeat_paras=False, 
        modifyattn=False, modifyrope=False, scale_score=0, 
        num_paraphrases=1, num_fewshots=5)

    modifyattn, modifyrope = False, False
    print("---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    # print("---- ❌ attention mask / ❌ rope modifications / ✅ scale score ----")
    # report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)

    modifyattn, modifyrope = True, False
    print("---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    modifyattn, modifyrope = False, True
    print("---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)

    
    # print("---- ✅ attention mask / ❌ rope modifications / ✅ scale score ----")
    # report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)

    modifyattn, modifyrope = True, True
    print("---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=False)
    
    print("---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----")
    report_accuracy(modifyattn=modifyattn, modifyrope=modifyrope, scale_score=True)
    print()
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.3912 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3209 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4210 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4452 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4390 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3514 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3787 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.3743 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3425 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3885 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.3829 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4790 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5454 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5273 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4681 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5553 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5502 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4046 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4724 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4483 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3692 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4716 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4685 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.5964 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6693 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6528 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6894 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6855 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5652 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6399 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.6153 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5104 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.6445 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.6408 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4282 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4069 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4399 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4839 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4813 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4127 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4412 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4402 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.3460 ==> 🏷️ 5paras 5shots 1QA    +Rope
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.4662 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.4624 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_7b ===================
# ---- Calculating baseline ----
# Acc: 0.4912 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5138 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5100 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5435 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_7b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4527 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4986 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.4748 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5029 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5015 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore
#
#
# =================== Model: qwen2.5_14b ===================
# ---- Calculating baseline ----
# Acc: 0.5364 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# File ./modifyattn.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyattn.modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# File ./modifyattn.modifyrope.scalescore20.singleparaqapair.5samples.5paras.feather does not exist!
#
#
# =================== Model: qwen2.5_14b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5254 ==> 🏷️ 1paras 5shots 1QA      (Baseline)
# ---- ❌ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5792 ==> 🏷️ 5paras 5shots 1QA
# ---- ✅ attention mask / ❌ rope modifications / ❌ scale score ----
# Acc: 0.5634 ==> 🏷️ 5paras 5shots 1QA   +Attn
# ---- ❌ attention mask / ✅ rope modifications / ❌ scale score ----
# File ./modifyrope.singleparaqapair.5samples.5paras.feather does not exist!
# ---- ✅ attention mask / ✅ rope modifications / ❌ scale score ----
# Acc: 0.5871 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope
# ---- ✅ attention mask / ✅ rope modifications / ✅ scale score ----
# Acc: 0.5854 ==> 🏷️ 5paras 5shots 1QA   +Attn +Rope +ScaleScore

# %%
# answers = [answers.tolist() for answers in para2["answer_lemmas"].tolist()]
# uuids = para2['uuid'].tolist()
# pred2, prompt2 = para2['predict_lemma'].tolist(), para2['paraphrases'].tolist()
# pred3, prompt3 = para3['predict_lemma'].tolist(), para3['paraphrases'].tolist()
# pred4, prompt4 = para4['predict_lemma'].tolist(), para4['paraphrases'].tolist()
# pred5, prompt5 = para5['predict_lemma'].tolist(), para5['paraphrases'].tolist()

# %%
# # for ans, p0, p2, p3, p4, p5 in zip(answers, base, pred2, pred3, pred4, pred5):
# iterator = zip(uuids, answers, pred2, prompt2, pred3, prompt3, pred4, prompt4, pred5, prompt5)
# for idx, (uuid, ans, p2, pp2, p3, pp3, p4, pp4, p5, pp5) in enumerate(iterator):
#     ans = [a.tolist() for a in ans]
#     baseline_sdf = baseline[baseline["uuid"] == uuid]
#     prompt = baseline_sdf["paraphrase"].tolist()[0]
#     pp2 = pp2.tolist()
#     pp3 = pp3.tolist()
#     pp4 = pp4.tolist()
#     pp5 = pp5.tolist()
    
#     pp2_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp2]
#     pp3_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp3]
#     pp4_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp4]
#     pp5_sep_predicts = [baseline_sdf[baseline_sdf["paraphrase"] == pp]["predict_lemma"].tolist()[0] for pp in pp5]
#     print("===")
#     print("Question:", prompt)
#     print("Answers:", ans)
#     print("Per-prompt predictions:", baseline_sdf["predict_lemma"].tolist())
#     # print("Baseline Prediction:", p0)
#     print(f"2-para Prediction:\t'{p2}' from: {pp2_sep_predicts}")
#     print(f"3-para Prediction:\t'{p3}' from: {pp3_sep_predicts}")
#     print(f"4-para Prediction:\t'{p4}' from: {pp4_sep_predicts}")
#     print(f"5-para Prediction:\t'{p5}' from: {pp5_sep_predicts}")
#     print()
