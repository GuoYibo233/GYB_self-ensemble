# %%
from functools import partial
from notebooks._utils import report_series_ensemble_accuracy_by_nparas
from notebooks._utils import calculate_parallel_ensemble_accuracy
from notebooks._utils import calculate_baseline_accuracy, get_layers

ds_name = "myriadlama"
dataset_root = "/home/xzhao/workspace/GYB_self-ensemble/datasets"

# %%
num_fewshots = 5
for model_name in ["llama3.2_1b", "llama3.2_1b_it", "llama3.2_3b", "llama3.2_3b_it", "llama3.1_8b", "llama3.1_8b_it"]:
# for model_name in ["qwen2.5_3b", "qwen2.5_3b_it", "qwen2.5_7b", "qwen2.5_7b_it", "qwen2.5_14b", "qwen2.5_14b_it"]:

    print(f"\n=================== Model: {model_name} ===================")
    dump_file_prefix = f"{dataset_root}/{ds_name}/{model_name}/myriadlama."
    report_accuracy = partial(
        report_series_ensemble_accuracy_by_nparas, 
        dump_file_prefix=dump_file_prefix,
        single_para_qapair=True,
        explicit_prompts=False,
        repeat_paras=False, 
        num_fewshots=num_fewshots, use_generated=True)
    
    print("---- Calculating baseline ----")
    calculate_baseline_accuracy(dataset_root, ds_name, model_name, num_fewshots, is_multichoice=False, by_probs=False)

    report_acc_base_setting = partial(
        calculate_parallel_ensemble_accuracy, 
        dump_file_prefix=dump_file_prefix, repeat_paras=False,
        num_paraphrases=5, num_fewshots=num_fewshots, num_samples=5,
        use_generation=True, by_probs=False, is_multichoice=False)

    print("---- Logits-based Ensemble (Average) ----")
    report_acc_base_setting(logits_ensemble_method="avg")
    
    print("---- Logits-based Ensemble (Maximum) ----")
    report_acc_base_setting(logits_ensemble_method="max")

    print("---- Logits-based Ensemble + Averaged Layer Output ----")
    multip_layavg_report = partial(report_acc_base_setting, logits_ensemble_method="avg", ensemble_method="layer_output_avg", multilayer=True)
    multip_layavg_report(token_mode="last", ensemble_alpha=1, ensemble_layer=get_layers(model_name))

    print("---- Logits-based Average + Averaged FFN Activation ----")
    multip_layavg_report = partial(report_acc_base_setting, logits_ensemble_method="avg", ensemble_method="ffn_activation_avg", multilayer=True)
    multip_layavg_report(token_mode="last", ensemble_alpha=1, ensemble_layer=get_layers(model_name))

    print("---- Logits-based Average + Maximum FFN Activation ----")
    multip_layavg_report = partial(report_acc_base_setting, logits_ensemble_method="avg", ensemble_method="ffn_activation_max", multilayer=True)
    multip_layavg_report(token_mode="last", ensemble_alpha=1, ensemble_layer=get_layers(model_name))

    print("---- Logits-based Maximum + Averaged FFN Activation ----")
    multip_layavg_report = partial(report_acc_base_setting, logits_ensemble_method="max", ensemble_method="ffn_activation_avg", multilayer=True)
    multip_layavg_report(token_mode="last", ensemble_alpha=1, ensemble_layer=get_layers(model_name))

    print("---- Logits-based Maximum + Maximum FFN Activation ----")
    multip_layavg_report = partial(report_acc_base_setting, logits_ensemble_method="max", ensemble_method="ffn_activation_max", multilayer=True)
    multip_layavg_report(token_mode="last", ensemble_alpha=1, ensemble_layer=get_layers(model_name))
# Out:
# =================== Model: llama3.2_1b ===================
# ---- Calculating baseline ----
# Acc: 0.3941 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.4665 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.4518 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.4797 ==> 🏷️ 5paras 5shots  layer_output_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.4736 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.3874 ==> 🏷️ 5paras 5shots  ffn_activation_max layer12 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.4807 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.4065 ==> 🏷️ 5paras 5shots  ffn_activation_max layer12 Multilayer alpha1 token-last
#
# =================== Model: llama3.2_1b_it ===================
# ---- Calculating baseline ----
# Acc: 0.3526 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.4182 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.4022 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.4185 ==> 🏷️ 5paras 5shots  layer_output_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.4178 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.3575 ==> 🏷️ 5paras 5shots  ffn_activation_max layer12 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.4234 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer12 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.3782 ==> 🏷️ 5paras 5shots  ffn_activation_max layer12 Multilayer alpha1 token-last
#
# =================== Model: llama3.2_3b ===================
# ---- Calculating baseline ----
# Acc: 0.4863 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.5772 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.5520 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.5796 ==> 🏷️ 5paras 5shots  layer_output_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.5720 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.4870 ==> 🏷️ 5paras 5shots  ffn_activation_max layer21 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.5760 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.5010 ==> 🏷️ 5paras 5shots  ffn_activation_max layer21 Multilayer alpha1 token-last
#
# =================== Model: llama3.2_3b_it ===================
# ---- Calculating baseline ----
# Acc: 0.4091 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.4995 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.4684 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.4930 ==> 🏷️ 5paras 5shots  layer_output_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.4927 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.4108 ==> 🏷️ 5paras 5shots  ffn_activation_max layer21 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.4986 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer21 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.4269 ==> 🏷️ 5paras 5shots  ffn_activation_max layer21 Multilayer alpha1 token-last
#
# =================== Model: llama3.1_8b ===================
# ---- Calculating baseline ----
# Acc: 0.5979 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.6957 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.6635 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.6994 ==> 🏷️ 5paras 5shots  layer_output_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.6940 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.6326 ==> 🏷️ 5paras 5shots  ffn_activation_max layer24 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.6829 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.6326 ==> 🏷️ 5paras 5shots  ffn_activation_max layer24 Multilayer alpha1 token-last
#
# =================== Model: llama3.1_8b_it ===================
# ---- Calculating baseline ----
# Acc: 0.5641 ==> 🏷️ baseline of average accuracy per-paraphrase
# ---- Logits-based Ensemble (Average) ----
# Acc: 0.6690 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble (Maximum) ----
# Acc: 0.6317 ==> 🏷️ 5paras 5shots  None layerNone  alpha1.0 token-all
# ---- Logits-based Ensemble + Averaged Layer Output ----
# Acc: 0.6675 ==> 🏷️ 5paras 5shots  layer_output_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Average + Averaged FFN Activation ----
# Acc: 0.6646 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Average + Maximum FFN Activation ----
# Acc: 0.5915 ==> 🏷️ 5paras 5shots  ffn_activation_max layer24 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Averaged FFN Activation ----
# Acc: 0.6559 ==> 🏷️ 5paras 5shots  ffn_activation_avg layer24 Multilayer alpha1 token-last
# ---- Logits-based Maximum + Maximum FFN Activation ----
# Acc: 0.5911 ==> 🏷️ 5paras 5shots  ffn_activation_max layer24 Multilayer alpha1 token-last
